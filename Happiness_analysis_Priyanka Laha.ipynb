# %%
#Importing the packages
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# # Read the data

# %%
my_data=pd.read_csv("happiness_score_dataset.csv")

# %% [markdown]
# # Check the shape of the data
# Dataset contains 158 rows and 12 columns

# %%
my_data.shape
# Out:
# (158, 12)

# %% [markdown]
# # Viewing the first ten rows of the dataset

# %%
my_data.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# # Viewing the last ten rows of the dataset

# %%
my_data.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# # The name of the columns

# %%
my_data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # More information of the data

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# 1. There is no null value in the dataset
# 2.Country and Region has datatype object
# 3.Happiness rank is a datatype integer
# 4.Rest nine columns have datatype float

# %% [markdown]
# # Check if there is any null value

# %%
my_data.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There is no null value in the dataset

# %% [markdown]
# # Check how many unique values in each column

# %%
my_data.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# 1.There are 10 ten unique value for the region
# 2.Most of the colums have all unique value for each data point

# %%
Region = pd.DataFrame(my_data['Region'].value_counts())
Region
# Out:
#                                  Region
# Sub-Saharan Africa                   40
# Central and Eastern Europe           29
# Latin America and Caribbean          22
# Western Europe                       21
# Middle East and Northern Africa      20
# Southeastern Asia                     9
# Southern Asia                         7
# Eastern Asia                          6
# Australia and New Zealand             2
# North America                         2

# %% [markdown]
# # Checking for duplicate values

# %%
my_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values in the colums

# %% [markdown]
# # Checking the to five happiest and top five least happiest country

# %%
country = my_data['Country'].iloc[:5] 
score = my_data['Happiness Score'].iloc[:5]

# %%
plt.title("Top Five Happiest Countries")
sns.barplot(x =score, y = country)
plt.show()

# %% [markdown]
# # Switzerland ,Iceland, Denmark, Norway and Canada are the top 5 happiest country.

# %%
country_rev = my_data['Country'].iloc[-5:] 
score_rev = my_data['Happiness Score'].iloc[-5:]

# %%
plt.title("Top Five Least Happiest countries")
sns.barplot(x =score_rev, y = country_rev)
plt.show()

# %% [markdown]
# # Togo is the least happiest country.Burundi ,Syria,Benin and Rwanda follows the least happiest chart.

# %% [markdown]
# # Dropping the columns Happiness Region, Country ,Happiness Rank, Dystopia Residuals for further analysis.

# %% [markdown]
#  Below three plots shows the relation between Happiness Score  and Economy (GDP per Capita), Family support ,Health
# (Life Expectancy),Freedom, Trust (Government Corruption), Generosity and also if they are correllated with each other.

# %%
my_data_new=my_data.drop(['Country','Region','Happiness Rank','Dystopia Residual','Standard Error'], axis=1)
my_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Score                158 non-null    float64
#  1   Economy (GDP per Capita)       158 non-null    float64
#  2   Family                         158 non-null    float64
#  3   Health (Life Expectancy)       158 non-null    float64
#  4   Freedom                        158 non-null    float64
#  5   Trust (Government Corruption)  158 non-null    float64
#  6   Generosity                     158 non-null    float64
# dtypes: float64(7)
# memory usage: 8.8 KB

# %%
corr_plot=my_data_new.corr()
figure, axis=plt.subplots(figsize=(10,10))
sns.heatmap(corr_plot, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1.The above heat map shows that Happiness score is highly dependent on economy (GDP), family and life expectency or health.
# 2.While life expectency or health or economy (GDP) is highly correlated with each other.

# %%
sns.pairplot(my_data_new,hue='Happiness Score')

# %% [markdown]
# The above pair plot also support our previous analysis but also found out that Generosity and Government corruption does not highly influence happiness score.

# %%
sns.pairplot(my_data_new,kind='reg',hue=)

# %% [markdown]
# 1.The above plot supports our previous anylysis and also found out all the feature variables are not normally distribute.
# 2.Generosity, Government Corruption ,Family are highly Skewed.

# %% [markdown]
# # Prepare the data for modeling.
# Scaling as the data is skewed

# %%
X = my_data_new.drop('Happiness Score',axis=1)
Y = my_data_new['Happiness Score']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
X.head()
# Out:
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  0.826132  0.962403                  0.918244  0.993789
# 1                  0.770412  1.000000                  0.924496  0.938841
# 2                  0.784113  0.970297                  0.853099  0.969615
# 3                  0.863099  0.949167                  0.863409  1.000000
# 4                  0.784592  0.943219                  0.883326  0.945112
#
#    Trust (Government Corruption)  Generosity
# 0                       0.760595    0.372895
# 1                       0.256292    0.548198
# 2                       0.876175    0.428947
# 3                       0.661394    0.435983
# 4                       0.597144    0.575602

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
Lin_reg = LinearRegression(normalize=True)
Rid = Ridge(alpha=0.5)

# %%
Lin_reg.fit(X_train,Y_train)
print(Lin_reg.score(X_test,Y_test))
# Out:
# 0.7226472024870768

# %%
Y_pred = Lin_reg.predict(X_test)
Y_pred
# Out:
# array([7.00790924, 4.282768  , 5.3959835 , 3.10137227, 5.56766734,
#        5.72925807, 6.22064286, 4.10878688, 4.51704911, 4.12686262,
#        6.23670873, 4.74875068, 5.17234973, 4.92720102, 6.57327094,
#        5.82741919, 4.45706795, 5.34652747, 6.87388917, 6.21330712,
#        7.11410219, 6.85359778, 4.94841618, 5.85820874, 6.19652755,
#        5.75959261, 4.37221257, 5.99761125, 6.51339531, 5.83589368,
#        4.58636566, 4.34418795, 5.97957288, 5.59300032, 5.11175008,
#        7.01118884, 7.1551117 , 3.95914795, 7.05488153, 4.83363027,
#        6.66831212, 3.67108861, 5.58366935, 5.89418413, 6.74270556,
#        4.70654146, 5.63302799, 4.24566388])

# %% [markdown]
# # Actual and predicted graph:Linear Regression

# %%
ax1 = sns.distplot(my_data_new['Happiness Score'],hist=False, color='red', label='Actual value')
sns.distplot(Y_pred,hist=False,color='blue',label='Predicted value',ax=ax1)
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # Ridge Regression

# %%
Rid = Ridge()
Rid.fit(X_train,Y_train)
print(R.score(X_test,Y_test))
# Out:
# 0.7507007985637423

# %%
Y_predRid = Rid.predict(X_test)
Y_predRid
# Out:
# array([6.90949276, 4.40466912, 5.39232775, 3.357403  , 5.54295544,
#        5.70481556, 6.14326026, 4.29833936, 4.50491473, 4.1564292 ,
#        6.20587127, 4.81665321, 5.15890331, 4.99606424, 6.46051335,
#        5.76965158, 4.53974612, 5.37547127, 6.77527977, 6.12053185,
#        7.00753469, 6.7676733 , 5.01142193, 5.80035829, 6.05836392,
#        5.68723964, 4.46521598, 5.92512041, 6.49052213, 5.80687213,
#        4.76728527, 4.40512319, 5.9578114 , 5.57751088, 5.17997037,
#        6.9584934 , 7.05940619, 4.05988086, 6.96578531, 4.83382934,
#        6.5721363 , 3.87731694, 5.54799379, 5.91209969, 6.64008794,
#        4.80306722, 5.59630349, 4.25320236])

# %% [markdown]
# # Actual and predicted graph:Ridge Regression

# %%
ax1 = sns.distplot(my_data_new['Happiness Score'],hist=False, color='r', label='Actual value')
sns.distplot(Y_predRid,hist=False,color='b',label='Predicted value',ax=ax1)
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor()
RF.fit(X_train,Y_train)

print(RF.score(X_test,Y_test))
# Out:
# 0.7197429058475401

# %%
print(RF.score(X_test,Y_test))
# Out:
# 0.7197429058475401

# %%
Y_predRF = RFR.predict(X_test)

# %% [markdown]
# # Actual and predicted graph:Random Forest

# %%
ax1 = sns.distplot(my_data_new['Happiness Score'],hist=False, color='r', label='Actual value')
sns.distplot(Y_predRF,hist=False,color='b',label='Predicted value',ax=ax1)
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # Suppot vector Regression

# %%
from sklearn.svm import SVR

SVR_Reg = SVR(kernel = "rbf")
SVR_Reg.fit(X_train, Y_train)
print(SVR_Reg.score(X_test, Y_test))
# Out:
# 0.6805511015027592

# %%
Y_predsvm = SVR_Reg.predict(X_test)

# %% [markdown]
# # Actual and predicted graph:Support Vector Regression

# %%
ax1 = sns.distplot(my_data_new['Happiness Score'],hist=False, color='r', label='Actual value')
sns.distplot(Y_predsvm,hist=False,color='b',label='Predicted value',ax=ax1)
plt.title("Actual vs Predicted")
plt.show()

# %% [markdown]
# # conclusion

# %% [markdown]
# # None of the model can predict Happiness score with high accuracy.May be Happiness is not entirely dependent on GDP, Economic situation, Family, Health or Government of the country.May be there are some other factors as well which influence our state of mind.
